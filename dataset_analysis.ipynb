# %% [markdown]
# ## Download the data

# %%
import pandas as pd

url = 'https://drive.google.com/uc?export=download&id=1sDjLEmqJi7I_RjMfOMqDVwc2YeUZhQRr'
data = pd.read_csv(url)

# %% [markdown]
# ## Check the data and its general info

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
# 5  female        group D                 high school      standard
# 6  female        group A           bachelor's degree      standard
# 7    male        group E                some college      standard
# 8    male        group D                 high school      standard
# 9    male        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ## Check the data on NaN values

# %%
data.isnull().any().any()
# Out:
# False

# %% [markdown]
# ### Add some NaN's and then replace them with 0's

# %%
import numpy as np

data_copy = data.copy()
data_copy.iloc[2:4, 5] = np.nan
data_copy.iloc[[2, 6, 9], 6] = np.nan
data_copy.iloc[5, 7] = np.nan

data_copy.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
# 5  female        group D                 high school      standard
# 6  female        group A           bachelor's degree      standard
# 7    male        group E                some college      standard
# 8    male        group D                 high school      standard
# 9    male        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed        67.0           67.0           63.0
# 1                    none        40.0           59.0           55.0
# ...

# %%
data_copy.fillna(0, inplace=True)
data_copy.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
# 5  female        group D                 high school      standard
# 6  female        group A           bachelor's degree      standard
# 7    male        group E                some college      standard
# 8    male        group D                 high school      standard
# 9    male        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed        67.0           67.0           63.0
# 1                    none        40.0           59.0           55.0
# ...

# %% [markdown]
# ## Delete all objects with NaN value

# %%
data_copy = data.copy()
data_copy.iloc[2:4, 5] = np.nan
data_copy.iloc[[2, 6, 9], 6] = np.nan
data_copy.iloc[5, 7] = np.nan

data_copy.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
# 5  female        group D                 high school      standard
# 6  female        group A           bachelor's degree      standard
# 7    male        group E                some college      standard
# 8    male        group D                 high school      standard
# 9    male        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed        67.0           67.0           63.0
# 1                    none        40.0           59.0           55.0
# ...

# %%
data_copy.dropna(inplace=True)
data_copy.head(10)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group A                 high school      standard
# 1   female        group D            some high school  free/reduced
# 4     male        group E          associate's degree      standard
# 7     male        group E                some college      standard
# 8     male        group D                 high school      standard
# 10    male        group E                some college      standard
# 11  female        group D                 high school      standard
# 12    male        group D          associate's degree      standard
# 13    male        group C                 high school      standard
# 14    male        group E            some high school      standard
#
#    test preparation course  math score  reading score  writing score
# 0                completed        67.0           67.0           63.0
# 1                     none        40.0           59.0           55.0
# ...

# %% [markdown]
# ## Create a new column with a total score for all exams

# %%
data['total score'] = data['math score'] + data['reading score'] + data['writing score']
data.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
# 5  female        group D                 high school      standard
# 6  female        group A           bachelor's degree      standard
# 7    male        group E                some college      standard
# 8    male        group D                 high school      standard
# 9    male        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          67             67             63
# 1                    none          40             59             55
# ...

# %% [markdown]
# ## Check what gender did better on exams

# %%
data.groupby('gender')[['total score', 'math score', 'reading score', 'writing score']].mean()
# Out:
#         total score  math score  reading score  writing score
# gender
# female   206.792961   63.196687      71.888199      71.708075
# male     199.719536   69.384913      66.305609      64.029014

# %% [markdown]
# ### As a conclusion, we can say that female students showed better results than male ones on average.

# %% [markdown]
# ## Check how lunch and test preparation impacted on results

# %%
data.groupby(['lunch', 'test preparation course'])['total score'].mean().reset_index()
# Out:
#           lunch test preparation course  total score
# 0  free/reduced               completed   198.218182
# 1  free/reduced                    none   175.411765
# 2      standard               completed   228.337778
# 3      standard                    none   206.576112

# %% [markdown]
# ### As we see, better lunch as well as completed preparation resulted in better total score on average.
