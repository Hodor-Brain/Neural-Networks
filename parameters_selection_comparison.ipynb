# %% [markdown]
# ## Import necessary libraries

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.layers import Dense

# %% [markdown]
# ## Load MNIST dataset

# %%
from keras.datasets import mnist

(x_train, y_train), (x_val, y_val) = tf.keras.datasets.fashion_mnist.load_data()

# %% [markdown]
# ## Convert answers and normalize inputs

# %%
y_train_oh = keras.utils.to_categorical(y_train, 10)
y_val_oh = keras.utils.to_categorical(y_val, 10)

x_train_float = x_train.astype(np.float64) / 255 - 0.5
x_val_float = x_val.astype(np.float64) / 255 - 0.5

# %% [markdown]
# ## Build and train model without hidden layers, with 400 neurons on input layer, using 10 epochs and batch size 10

# %%
keras.backend.clear_session()
model1 = keras.Sequential()
model1.add(Dense(400, input_dim=784, activation='relu'))
model1.add(Dense(10, activation='softmax'))

model1.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model1.fit(
    x_train_float.reshape(-1, 28*28),
    y_train_oh,
    batch_size=10,
    epochs=10,
    validation_data=(x_val_float.reshape(-1, 28*28), y_val_oh)
)
# Out:
# Epoch 1/10
# 6000/6000 [==============================] - 54s 9ms/step - loss: 0.4802 - accuracy: 0.8250 - val_loss: 0.4479 - val_accuracy: 0.8350
# Epoch 2/10
# 6000/6000 [==============================] - 54s 9ms/step - loss: 0.3704 - accuracy: 0.8628 - val_loss: 0.4042 - val_accuracy: 0.8536
# Epoch 3/10
# 6000/6000 [==============================] - 45s 7ms/step - loss: 0.3327 - accuracy: 0.8777 - val_loss: 0.3909 - val_accuracy: 0.8618
# Epoch 4/10
# 6000/6000 [==============================] - 44s 7ms/step - loss: 0.3107 - accuracy: 0.8865 - val_loss: 0.3973 - val_accuracy: 0.8585
# Epoch 5/10
# 6000/6000 [==============================] - 40s 7ms/step - loss: 0.2930 - accuracy: 0.8914 - val_loss: 0.3754 - val_accuracy: 0.8681
# Epoch 6/10
# 6000/6000 [==============================] - 38s 6ms/step - loss: 0.2779 - accuracy: 0.8977 - val_loss: 0.3755 - val_accuracy: 0.8722
# Epoch 7/10
# 6000/6000 [==============================] - 38s 6ms/step - loss: 0.2654 - accuracy: 0.9010 - val_loss: 0.3576 - val_accuracy: 0.8817
# Epoch 8/10
# 6000/6000 [==============================] - 38s 6ms/step - loss: 0.2535 - accuracy: 0.9052 - val_loss: 0.3586 - val_accuracy: 0.8819
# Epoch 9/10
# 6000/6000 [==============================] - 38s 6ms/step - loss: 0.2446 - accuracy: 0.9100 - val_loss: 0.3881 - val_accuracy: 0.8721
# Epoch 10/10
# 6000/6000 [==============================] - 38s 6ms/step - loss: 0.2386 - accuracy: 0.9115 - val_loss: 0.3896 - val_accuracy: 0.8718

# %%
score = model1.evaluate(x_val_float.reshape(-1, 28*28), y_val_oh, verbose=0)
print('Test loss:', score[0], '\nTest accuracy:', score[1])
# Out:
# Test loss: 0.3896038234233856
# Test accuracy: 0.8718000054359436

# %% [markdown]
# ## Build and train model using 1 hidden layer with 800 neurons, 1200 neurons on input layer, using 30 epochs and batch size 500

# %%
keras.backend.clear_session()
model2 = keras.Sequential()
model2.add(Dense(1200, input_dim=784, activation='relu'))
model2.add(Dense(800, activation='relu'))
model2.add(Dense(10, activation='softmax'))

model2.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model2.fit(
    x_train_float.reshape(-1, 28*28),
    y_train_oh,
    batch_size=500,
    epochs=30,
    validation_data=(x_val_float.reshape(-1, 28*28), y_val_oh)
)

score = model2.evaluate(x_val_float.reshape(-1, 28*28), y_val_oh, verbose=0)
print('Test loss:', score[0], '\nTest accuracy:', score[1])
# Out:
# Epoch 1/30
# 120/120 [==============================] - 16s 128ms/step - loss: 0.5133 - accuracy: 0.8138 - val_loss: 0.4067 - val_accuracy: 0.8491
# Epoch 2/30
# 120/120 [==============================] - 15s 126ms/step - loss: 0.3552 - accuracy: 0.8712 - val_loss: 0.3838 - val_accuracy: 0.8614
# Epoch 3/30
# 120/120 [==============================] - 16s 131ms/step - loss: 0.3138 - accuracy: 0.8838 - val_loss: 0.3661 - val_accuracy: 0.8636
# Epoch 4/30
# 120/120 [==============================] - 20s 166ms/step - loss: 0.2856 - accuracy: 0.8954 - val_loss: 0.3603 - val_accuracy: 0.8711
# Epoch 5/30
# 120/120 [==============================] - 16s 134ms/step - loss: 0.2674 - accuracy: 0.9012 - val_loss: 0.3346 - val_accuracy: 0.8807
# Epoch 6/30
# 120/120 [==============================] - 15s 124ms/step - loss: 0.2484 - accuracy: 0.9082 - val_loss: 0.3476 - val_accuracy: 0.8764
# Epoch 7/30
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2347 - accuracy: 0.9131 - val_loss: 0.3194 - val_accuracy: 0.8868
# Epoch 8/30
# 120/120 [==============================] - 16s 132ms/step - loss: 0.2190 - accuracy: 0.9179 - val_loss: 0.3176 - val_accuracy: 0.8901
# Epoch 9/30
# 120/120 [==============================] - 15s 125ms/step - loss: 0.2103 - accuracy: 0.9209 - val_loss: 0.3309 - val_accuracy: 0.8850
# Epoch 10/30
# 120/120 [==============================] - 16s 135ms/step - loss: 0.1941 - accuracy: 0.9267 - val_loss: 0.3281 - val_accuracy: 0.8881
# Epoch 11/30
# 120/120 [==============================] - 17s 140ms/step - loss: 0.1832 - accuracy: 0.9301 - val_loss: 0.3289 - val_accuracy: 0.8935
# Epoch 12/30
# 120/120 [==============================] - 18s 152ms/step - loss: 0.1716 - accuracy: 0.9344 - val_loss: 0.3373 - val_accuracy: 0.8885
# Epoch 13/30
# 120/120 [==============================] - 19s 155ms/step - loss: 0.1601 - accuracy: 0.9403 - val_loss: 0.3515 - val_accuracy: 0.8896
# Epoch 14/30
# 120/120 [==============================] - 16s 136ms/step - loss: 0.1513 - accuracy: 0.9424 - val_loss: 0.3700 - val_accuracy: 0.8869
# Epoch 15/30
# 120/120 [==============================] - 15s 123ms/step - loss: 0.1479 - accuracy: 0.9448 - val_loss: 0.3521 - val_accuracy: 0.8896
# Epoch 16/30
# 120/120 [==============================] - 16s 130ms/step - loss: 0.1352 - accuracy: 0.9491 - val_loss: 0.3612 - val_accuracy: 0.8863
# Epoch 17/30
# 120/120 [==============================] - 16s 136ms/step - loss: 0.1231 - accuracy: 0.9540 - val_loss: 0.3549 - val_accuracy: 0.8909
# Epoch 18/30
# 120/120 [==============================] - 16s 132ms/step - loss: 0.1159 - accuracy: 0.9565 - val_loss: 0.3890 - val_accuracy: 0.8862
# Epoch 19/30
# 120/120 [==============================] - 19s 158ms/step - loss: 0.1135 - accuracy: 0.9574 - val_loss: 0.3755 - val_accuracy: 0.8936
# Epoch 20/30
# 120/120 [==============================] - 17s 141ms/step - loss: 0.1087 - accuracy: 0.9585 - val_loss: 0.3842 - val_accuracy: 0.8981
# Epoch 21/30
# 120/120 [==============================] - 17s 138ms/step - loss: 0.1010 - accuracy: 0.9617 - val_loss: 0.3945 - val_accuracy: 0.8929
# Epoch 22/30
# 120/120 [==============================] - 16s 131ms/step - loss: 0.0935 - accuracy: 0.9642 - val_loss: 0.4043 - val_accuracy: 0.8909
# Epoch 23/30
# 120/120 [==============================] - 18s 152ms/step - loss: 0.0879 - accuracy: 0.9673 - val_loss: 0.4208 - val_accuracy: 0.8894
# Epoch 24/30
# 120/120 [==============================] - 17s 143ms/step - loss: 0.0808 - accuracy: 0.9699 - val_loss: 0.4165 - val_accuracy: 0.8957
# Epoch 25/30
# 120/120 [==============================] - 15s 125ms/step - loss: 0.0746 - accuracy: 0.9716 - val_loss: 0.4378 - val_accuracy: 0.8939
# Epoch 26/30
# 120/120 [==============================] - 16s 130ms/step - loss: 0.0745 - accuracy: 0.9714 - val_loss: 0.4474 - val_accuracy: 0.8947
# Epoch 27/30
# 120/120 [==============================] - 17s 143ms/step - loss: 0.0753 - accuracy: 0.9713 - val_loss: 0.4602 - val_accuracy: 0.8849
# Epoch 28/30
# 120/120 [==============================] - 16s 135ms/step - loss: 0.0620 - accuracy: 0.9766 - val_loss: 0.4757 - val_accuracy: 0.8949
# Epoch 29/30
# 120/120 [==============================] - 15s 124ms/step - loss: 0.0581 - accuracy: 0.9785 - val_loss: 0.4817 - val_accuracy: 0.8956
# Epoch 30/30
# 120/120 [==============================] - 18s 153ms/step - loss: 0.0530 - accuracy: 0.9803 - val_loss: 0.4777 - val_accuracy: 0.8940
# Test loss: 0.47767412662506104
# Test accuracy: 0.8939999938011169

# %% [markdown]
# ## Build and train model using 3 hidden layers with 600, 400 and 300 neurons respectively, 800 neurons on input layer, using 20 epochs and batch size 100

# %%
keras.backend.clear_session()
model3 = keras.Sequential()
model3.add(Dense(800, input_dim=784, activation='relu'))
model3.add(Dense(600, activation='relu'))
model3.add(Dense(400, activation='relu'))
model3.add(Dense(300, activation='relu'))
model3.add(Dense(10, activation='softmax'))

model3.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model3.fit(
    x_train_float.reshape(-1, 28*28),
    y_train_oh,
    batch_size=100,
    epochs=20,
    validation_data=(x_val_float.reshape(-1, 28*28), y_val_oh)
)

score = model3.evaluate(x_val_float.reshape(-1, 28*28), y_val_oh, verbose=0)
print('Test loss:', score[0], '\nTest accuracy:', score[1])
# Out:
# Epoch 1/20
# 600/600 [==============================] - 21s 33ms/step - loss: 0.4925 - accuracy: 0.8204 - val_loss: 0.4338 - val_accuracy: 0.8426
# Epoch 2/20
# 600/600 [==============================] - 22s 36ms/step - loss: 0.3676 - accuracy: 0.8656 - val_loss: 0.3654 - val_accuracy: 0.8669
# Epoch 3/20
# 600/600 [==============================] - 20s 33ms/step - loss: 0.3302 - accuracy: 0.8783 - val_loss: 0.3894 - val_accuracy: 0.8578
# Epoch 4/20
# 600/600 [==============================] - 22s 36ms/step - loss: 0.3075 - accuracy: 0.8861 - val_loss: 0.3383 - val_accuracy: 0.8801
# Epoch 5/20
# 600/600 [==============================] - 25s 42ms/step - loss: 0.2851 - accuracy: 0.8943 - val_loss: 0.3435 - val_accuracy: 0.8786
# Epoch 6/20
# 600/600 [==============================] - 27s 45ms/step - loss: 0.2688 - accuracy: 0.9004 - val_loss: 0.3500 - val_accuracy: 0.8796
# Epoch 7/20
# 600/600 [==============================] - 24s 40ms/step - loss: 0.2529 - accuracy: 0.9051 - val_loss: 0.3528 - val_accuracy: 0.8797
# Epoch 8/20
# 600/600 [==============================] - 24s 41ms/step - loss: 0.2370 - accuracy: 0.9103 - val_loss: 0.3324 - val_accuracy: 0.8834
# Epoch 9/20
# 600/600 [==============================] - 22s 37ms/step - loss: 0.2262 - accuracy: 0.9141 - val_loss: 0.3401 - val_accuracy: 0.8834
# Epoch 10/20
# 600/600 [==============================] - 25s 41ms/step - loss: 0.2138 - accuracy: 0.9194 - val_loss: 0.3445 - val_accuracy: 0.8886
# Epoch 11/20
# 600/600 [==============================] - 23s 38ms/step - loss: 0.2046 - accuracy: 0.9234 - val_loss: 0.3580 - val_accuracy: 0.8821
# Epoch 12/20
# 600/600 [==============================] - 25s 41ms/step - loss: 0.1940 - accuracy: 0.9260 - val_loss: 0.3608 - val_accuracy: 0.8873
# Epoch 13/20
# 600/600 [==============================] - 19s 32ms/step - loss: 0.1821 - accuracy: 0.9300 - val_loss: 0.3561 - val_accuracy: 0.8877
# Epoch 14/20
# 600/600 [==============================] - 20s 34ms/step - loss: 0.1742 - accuracy: 0.9332 - val_loss: 0.3998 - val_accuracy: 0.8801
# Epoch 15/20
# 600/600 [==============================] - 19s 32ms/step - loss: 0.1671 - accuracy: 0.9363 - val_loss: 0.3725 - val_accuracy: 0.8880
# Epoch 16/20
# 600/600 [==============================] - 21s 34ms/step - loss: 0.1573 - accuracy: 0.9385 - val_loss: 0.3592 - val_accuracy: 0.8933
# Epoch 17/20
# 600/600 [==============================] - 19s 32ms/step - loss: 0.1466 - accuracy: 0.9437 - val_loss: 0.3961 - val_accuracy: 0.8898
# Epoch 18/20
# 600/600 [==============================] - 21s 34ms/step - loss: 0.1429 - accuracy: 0.9448 - val_loss: 0.4236 - val_accuracy: 0.8900
# Epoch 19/20
# 600/600 [==============================] - 20s 33ms/step - loss: 0.1377 - accuracy: 0.9472 - val_loss: 0.4091 - val_accuracy: 0.8897
# Epoch 20/20
# 600/600 [==============================] - 21s 34ms/step - loss: 0.1260 - accuracy: 0.9510 - val_loss: 0.4053 - val_accuracy: 0.8906
# Test loss: 0.4052708148956299
# Test accuracy: 0.8906000256538391

# %% [markdown]
# ## Build and train model using 2 hidden layers with 400 and 200 neurons respectively, 600 neurons on input layer, using 15 epochs and batch size 200

# %%
keras.backend.clear_session()
model4 = keras.Sequential()
model4.add(Dense(600, input_dim=784, activation='relu'))
model4.add(Dense(400, activation='relu'))
model4.add(Dense(200, activation='relu'))
model4.add(Dense(10, activation='softmax'))

model4.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model4.fit(
    x_train_float.reshape(-1, 28*28),
    y_train_oh,
    batch_size=200,
    epochs=15,
    validation_data=(x_val_float.reshape(-1, 28*28), y_val_oh)
)

score = model4.evaluate(x_val_float.reshape(-1, 28*28), y_val_oh, verbose=0)
print('Test loss:', score[0], '\nTest accuracy:', score[1])
# Out:
# Epoch 1/15
# 300/300 [==============================] - 9s 27ms/step - loss: 0.4826 - accuracy: 0.8233 - val_loss: 0.4093 - val_accuracy: 0.8532
# Epoch 2/15
# 300/300 [==============================] - 9s 29ms/step - loss: 0.3579 - accuracy: 0.8686 - val_loss: 0.3762 - val_accuracy: 0.8629
# Epoch 3/15
# 300/300 [==============================] - 8s 26ms/step - loss: 0.3176 - accuracy: 0.8825 - val_loss: 0.3742 - val_accuracy: 0.8631
# Epoch 4/15
# 300/300 [==============================] - 8s 27ms/step - loss: 0.2929 - accuracy: 0.8901 - val_loss: 0.3381 - val_accuracy: 0.8764
# Epoch 5/15
# 300/300 [==============================] - 9s 30ms/step - loss: 0.2738 - accuracy: 0.8982 - val_loss: 0.3320 - val_accuracy: 0.8784
# Epoch 6/15
# 300/300 [==============================] - 8s 26ms/step - loss: 0.2566 - accuracy: 0.9038 - val_loss: 0.3321 - val_accuracy: 0.8821
# Epoch 7/15
# 300/300 [==============================] - 9s 30ms/step - loss: 0.2421 - accuracy: 0.9082 - val_loss: 0.3318 - val_accuracy: 0.8834
# Epoch 8/15
# 300/300 [==============================] - 9s 29ms/step - loss: 0.2304 - accuracy: 0.9137 - val_loss: 0.3676 - val_accuracy: 0.8653
# Epoch 9/15
# 300/300 [==============================] - 7s 25ms/step - loss: 0.2153 - accuracy: 0.9193 - val_loss: 0.3303 - val_accuracy: 0.8859
# Epoch 10/15
# 300/300 [==============================] - 9s 29ms/step - loss: 0.2072 - accuracy: 0.9215 - val_loss: 0.3415 - val_accuracy: 0.8832
# Epoch 11/15
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1941 - accuracy: 0.9269 - val_loss: 0.3308 - val_accuracy: 0.8903
# Epoch 12/15
# 300/300 [==============================] - 8s 25ms/step - loss: 0.1836 - accuracy: 0.9296 - val_loss: 0.3313 - val_accuracy: 0.8901
# Epoch 13/15
# 300/300 [==============================] - 9s 29ms/step - loss: 0.1751 - accuracy: 0.9332 - val_loss: 0.3419 - val_accuracy: 0.8887
# Epoch 14/15
# 300/300 [==============================] - 9s 30ms/step - loss: 0.1619 - accuracy: 0.9385 - val_loss: 0.3533 - val_accuracy: 0.8882
# Epoch 15/15
# 300/300 [==============================] - 7s 25ms/step - loss: 0.1539 - accuracy: 0.9411 - val_loss: 0.3629 - val_accuracy: 0.8812
# Test loss: 0.36286067962646484
# Test accuracy: 0.8812000155448914

# %% [markdown]
# ## Build and train model using 4 hidden layers with 300, 400, 600 and 800 neurons respectively, 800 neurons on input layer, using 25 epochs and batch size 50

# %%
keras.backend.clear_session()
model5 = keras.Sequential()
model5.add(Dense(800, input_dim=784, activation='relu'))
model5.add(Dense(300, activation='relu'))
model5.add(Dense(400, activation='relu'))
model5.add(Dense(600, activation='relu'))
model5.add(Dense(800, activation='relu'))
model5.add(Dense(10, activation='softmax'))

model5.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model5.fit(
    x_train_float.reshape(-1, 28*28),
    y_train_oh,
    batch_size=50,
    epochs=25,
    validation_data=(x_val_float.reshape(-1, 28*28), y_val_oh)
)

score = model5.evaluate(x_val_float.reshape(-1, 28*28), y_val_oh, verbose=0)
print('Test loss:', score[0], '\nTest accuracy:', score[1])
# Out:
# Epoch 1/25
# 1200/1200 [==============================] - 40s 32ms/step - loss: 0.5285 - accuracy: 0.8096 - val_loss: 0.4854 - val_accuracy: 0.8212
# Epoch 2/25
# 1200/1200 [==============================] - 38s 31ms/step - loss: 0.3999 - accuracy: 0.8557 - val_loss: 0.4154 - val_accuracy: 0.8472
# Epoch 3/25
# 1200/1200 [==============================] - 37s 31ms/step - loss: 0.3568 - accuracy: 0.8718 - val_loss: 0.4290 - val_accuracy: 0.8577
# Epoch 4/25
# 1200/1200 [==============================] - 37s 31ms/step - loss: 0.3280 - accuracy: 0.8794 - val_loss: 0.3712 - val_accuracy: 0.8692
# Epoch 5/25
# 1200/1200 [==============================] - 37s 31ms/step - loss: 0.3090 - accuracy: 0.8865 - val_loss: 0.3586 - val_accuracy: 0.8763
# Epoch 6/25
# 1200/1200 [==============================] - 39s 32ms/step - loss: 0.2929 - accuracy: 0.8926 - val_loss: 0.3512 - val_accuracy: 0.8780
# Epoch 7/25
# 1200/1200 [==============================] - 37s 31ms/step - loss: 0.2796 - accuracy: 0.8970 - val_loss: 0.3423 - val_accuracy: 0.8826
# Epoch 8/25
# 1200/1200 [==============================] - 38s 32ms/step - loss: 0.2644 - accuracy: 0.9026 - val_loss: 0.3485 - val_accuracy: 0.8799
# Epoch 9/25
# 1200/1200 [==============================] - 38s 32ms/step - loss: 0.2532 - accuracy: 0.9063 - val_loss: 0.3993 - val_accuracy: 0.8695
# Epoch 10/25
# 1200/1200 [==============================] - 38s 32ms/step - loss: 0.2423 - accuracy: 0.9102 - val_loss: 0.3503 - val_accuracy: 0.8815
# Epoch 11/25
# 1200/1200 [==============================] - 39s 33ms/step - loss: 0.2335 - accuracy: 0.9139 - val_loss: 0.3354 - val_accuracy: 0.8860
# Epoch 12/25
# 1200/1200 [==============================] - 37s 31ms/step - loss: 0.2229 - accuracy: 0.9170 - val_loss: 0.3713 - val_accuracy: 0.8792
# Epoch 13/25
# 1200/1200 [==============================] - 36s 30ms/step - loss: 0.2209 - accuracy: 0.9172 - val_loss: 0.3589 - val_accuracy: 0.8846
# Epoch 14/25
# 1200/1200 [==============================] - 36s 30ms/step - loss: 0.2090 - accuracy: 0.9230 - val_loss: 0.3789 - val_accuracy: 0.8841
# Epoch 15/25
# 1200/1200 [==============================] - 38s 31ms/step - loss: 0.2038 - accuracy: 0.9250 - val_loss: 0.3719 - val_accuracy: 0.8845
# Epoch 16/25
# 1200/1200 [==============================] - 39s 33ms/step - loss: 0.1978 - accuracy: 0.9259 - val_loss: 0.3567 - val_accuracy: 0.8865
# Epoch 17/25
# 1200/1200 [==============================] - 38s 32ms/step - loss: 0.1864 - accuracy: 0.9301 - val_loss: 0.3797 - val_accuracy: 0.8877
# Epoch 18/25
# 1200/1200 [==============================] - 37s 31ms/step - loss: 0.1790 - accuracy: 0.9326 - val_loss: 0.3951 - val_accuracy: 0.8897
# Epoch 19/25
# 1200/1200 [==============================] - 37s 30ms/step - loss: 0.1808 - accuracy: 0.9329 - val_loss: 0.4299 - val_accuracy: 0.8886
# Epoch 20/25
# 1200/1200 [==============================] - 38s 32ms/step - loss: 0.1694 - accuracy: 0.9361 - val_loss: 0.3857 - val_accuracy: 0.8925
# Epoch 21/25
# 1200/1200 [==============================] - 37s 31ms/step - loss: 0.1631 - accuracy: 0.9383 - val_loss: 0.4198 - val_accuracy: 0.8891
# Epoch 22/25
# 1200/1200 [==============================] - 37s 31ms/step - loss: 0.1656 - accuracy: 0.9399 - val_loss: 0.3946 - val_accuracy: 0.8893
# Epoch 23/25
# 1200/1200 [==============================] - 37s 30ms/step - loss: 0.1593 - accuracy: 0.9415 - val_loss: 0.3715 - val_accuracy: 0.8933
# Epoch 24/25
# 1200/1200 [==============================] - 38s 32ms/step - loss: 0.1477 - accuracy: 0.9448 - val_loss: 0.4083 - val_accuracy: 0.8892
# Epoch 25/25
# 1200/1200 [==============================] - 39s 33ms/step - loss: 0.1431 - accuracy: 0.9468 - val_loss: 0.4198 - val_accuracy: 0.8829
# Test loss: 0.4198366105556488
# Test accuracy: 0.8828999996185303

# %% [markdown]
# ## Build and train model using 2 hidden layers with 600 and 400 neurons respectively, 1200 neurons on input layer, using 20 epochs and batch size 200

# %%
keras.backend.clear_session()
model6 = keras.Sequential()
model6.add(Dense(1200, input_dim=784, activation='relu'))
model6.add(Dense(600, activation='relu'))
model6.add(Dense(400, activation='relu'))
model6.add(Dense(10, activation='softmax'))

model6.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model6.fit(
    x_train_float.reshape(-1, 28*28),
    y_train_oh,
    batch_size=200,
    epochs=20,
    validation_data=(x_val_float.reshape(-1, 28*28), y_val_oh)
)

score = model6.evaluate(x_val_float.reshape(-1, 28*28), y_val_oh, verbose=0)
print('Test loss:', score[0], '\nTest accuracy:', score[1])
# Out:
# Epoch 1/20
# 300/300 [==============================] - 21s 66ms/step - loss: 0.4824 - accuracy: 0.8228 - val_loss: 0.4391 - val_accuracy: 0.8418
# Epoch 2/20
# 300/300 [==============================] - 18s 61ms/step - loss: 0.3519 - accuracy: 0.8698 - val_loss: 0.4034 - val_accuracy: 0.8520
# Epoch 3/20
# 300/300 [==============================] - 20s 68ms/step - loss: 0.3166 - accuracy: 0.8826 - val_loss: 0.3518 - val_accuracy: 0.8738
# Epoch 4/20
# 300/300 [==============================] - 18s 60ms/step - loss: 0.2865 - accuracy: 0.8927 - val_loss: 0.3344 - val_accuracy: 0.8779
# Epoch 5/20
# 300/300 [==============================] - 19s 62ms/step - loss: 0.2698 - accuracy: 0.8990 - val_loss: 0.3473 - val_accuracy: 0.8814
# Epoch 6/20
# 300/300 [==============================] - 19s 64ms/step - loss: 0.2549 - accuracy: 0.9050 - val_loss: 0.3460 - val_accuracy: 0.8736
# Epoch 7/20
# 300/300 [==============================] - 18s 61ms/step - loss: 0.2377 - accuracy: 0.9111 - val_loss: 0.3632 - val_accuracy: 0.8721
# Epoch 8/20
# 300/300 [==============================] - 21s 70ms/step - loss: 0.2243 - accuracy: 0.9151 - val_loss: 0.3552 - val_accuracy: 0.8811
# Epoch 9/20
# 300/300 [==============================] - 18s 60ms/step - loss: 0.2133 - accuracy: 0.9196 - val_loss: 0.3382 - val_accuracy: 0.8878
# Epoch 10/20
# 300/300 [==============================] - 19s 64ms/step - loss: 0.2011 - accuracy: 0.9233 - val_loss: 0.3502 - val_accuracy: 0.8851
# Epoch 11/20
# 300/300 [==============================] - 18s 61ms/step - loss: 0.1903 - accuracy: 0.9280 - val_loss: 0.3429 - val_accuracy: 0.8888
# Epoch 12/20
# 300/300 [==============================] - 20s 66ms/step - loss: 0.1775 - accuracy: 0.9318 - val_loss: 0.3496 - val_accuracy: 0.8857
# Epoch 13/20
# 300/300 [==============================] - 18s 61ms/step - loss: 0.1683 - accuracy: 0.9355 - val_loss: 0.3461 - val_accuracy: 0.8913
# Epoch 14/20
# 300/300 [==============================] - 19s 62ms/step - loss: 0.1569 - accuracy: 0.9403 - val_loss: 0.3987 - val_accuracy: 0.8872
# Epoch 15/20
# 300/300 [==============================] - 19s 64ms/step - loss: 0.1487 - accuracy: 0.9433 - val_loss: 0.3640 - val_accuracy: 0.8890
# Epoch 16/20
# 300/300 [==============================] - 18s 62ms/step - loss: 0.1389 - accuracy: 0.9475 - val_loss: 0.3719 - val_accuracy: 0.8921
# Epoch 17/20
# 300/300 [==============================] - 21s 71ms/step - loss: 0.1371 - accuracy: 0.9475 - val_loss: 0.3908 - val_accuracy: 0.8915
# Epoch 18/20
# 300/300 [==============================] - 19s 62ms/step - loss: 0.1270 - accuracy: 0.9509 - val_loss: 0.3831 - val_accuracy: 0.8939
# Epoch 19/20
# 300/300 [==============================] - 20s 67ms/step - loss: 0.1161 - accuracy: 0.9550 - val_loss: 0.4059 - val_accuracy: 0.8917
# Epoch 20/20
# 300/300 [==============================] - 19s 62ms/step - loss: 0.1124 - accuracy: 0.9564 - val_loss: 0.4162 - val_accuracy: 0.8890
# Test loss: 0.416172593832016
# Test accuracy: 0.8889999985694885

# %% [markdown]
# ## As a conclusion, the most accurate model was model №2 with 1200 neurons on input layer, 1 hidden layer with 800 neurons, using 30 epochs and batch size 500
